# %% [markdown]
# # Testing notebook

# %%
import pandas as pd
import bamboolib as bam

# %%
df = pd.read_csv('https://www.fhfa.gov/HPI_master.csv').convert_dtypes()

# %%
df
# Out:
#              hpi_type     hpi_flavor  frequency                   level  \
# 0         traditional  purchase-only    monthly  USA or Census Division
# 1         traditional  purchase-only    monthly  USA or Census Division
# 2         traditional  purchase-only    monthly  USA or Census Division
# 3         traditional  purchase-only    monthly  USA or Census Division
# 4         traditional  purchase-only    monthly  USA or Census Division
# ...               ...            ...        ...                     ...
# 113875  developmental  purchase-only  quarterly             Puerto Rico
# 113876  developmental  purchase-only  quarterly             Puerto Rico
# 113877  developmental  purchase-only  quarterly             Puerto Rico
# 113878  developmental  purchase-only  quarterly             Puerto Rico
# 113879  developmental  purchase-only  quarterly             Puerto Rico
#
#                          place_name place_id    yr  period  index_nsa  \
# ...

# %%
df2['yr'].hist()
# Out:
# <AxesSubplot:>
